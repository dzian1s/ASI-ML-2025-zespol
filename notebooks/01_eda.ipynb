# %%
import pandas as pd

# %%
data = pd.read_csv("../data/01_raw/airbnb_sample.csv")

# %%
data
# Out:
#            id                                               name    host_id  \
# 0      317905                Come and go as  you please in BKLN!    1631733
# 1    34205267            Spacious, sunny room in Queens/Brooklyn     913940
# 2    12342297     Private bedroom in high-ceiling 4BR apartment!   19953913
# 3    33527778   Sonder | Stock Exchange | Stunning 3BR + Kitchen  219517861
# 4    13136376                    Spacious 2 Bedroom with Balcony   16110448
# ..        ...                                                ...        ...
# 495  33113990      Adorable walk-up on the high line—with views!    2919299
# 496  32518068  Super cute 1 bedroom apartment close to TimeSq...    7441368
# 497  29852402           Flex Room With Private Patio in Bushwick   60258049
# 498  13674338                      Sunny 2 Bedroom Best Location   75029289
# 499   1956467            Big, beautiful, central 1BD in Brooklyn    1500550
#
# ...

# %%
data.info()

# %%
data.isnull().sum()
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           0
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                       106
# reviews_per_month                 106
# calculated_host_listings_count      0
# availability_365                    0
# dtype: int64

# %%
data.describe()
# Out:
#                  id       host_id    latitude   longitude        price  \
# count  5.000000e+02  5.000000e+02  500.000000  500.000000   500.000000
# mean   1.845701e+07  6.775540e+07   40.728312  -73.951452   137.866000
# std    1.074447e+07  7.704333e+07    0.055662    0.045274   128.944412
# min    5.022000e+03  2.787000e+03   40.577600  -74.109890    20.000000
# 25%    9.462657e+06  7.392421e+06   40.688300  -73.983015    68.500000
# 50%    1.906872e+07  3.308106e+07   40.722190  -73.953200   100.000000
# 75%    2.783694e+07  1.072108e+08   40.762767  -73.933825   160.000000
# max    3.637967e+07  2.723428e+08   40.901750  -73.754370  1550.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count      500.000000         500.000000         394.000000
# mean         6.640000          22.994000           1.292716
# std         10.998378          42.707444           1.707682
# min          1.000000           0.000000           0.020000
# ...

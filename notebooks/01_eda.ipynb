# %%
import pandas as pd

df = pd.read_csv("../data/01_raw/AB_NYC_2019.csv")
sample_df = df.sample(500, random_state=42)

sample_df.to_csv("../data/01_raw/airbnb_sample.csv", index=False)

print("saved")
# Out:
# saved

# %%
pd.read_csv("../data/01_raw/airbnb_sample.csv").head()
# Out:
#          id                                              name    host_id  \
# 0    317905               Come and go as  you please in BKLN!    1631733
# 1  34205267           Spacious, sunny room in Queens/Brooklyn     913940
# 2  12342297    Private bedroom in high-ceiling 4BR apartment!   19953913
# 3  33527778  Sonder | Stock Exchange | Stunning 3BR + Kitchen  219517861
# 4  13136376                   Spacious 2 Bedroom with Balcony   16110448
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          Jane            Brooklyn          Kensington  40.64354  -73.97777
# 1     Giancarlo              Queens           Ridgewood  40.70666  -73.90779
# 2     Alejandro           Manhattan      Hell's Kitchen  40.76116  -73.99016
# 3  Sonder (NYC)           Manhattan  Financial District  40.70763  -74.01050
# 4        Gingie           Manhattan         East Harlem  40.79658  -73.93287
#
# ...
